# %%
import matplotlib.pyplot as plt

# %%
#first diagram
squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares)

plt.show()

# %%
#comments
squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares, linewidth=3)

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

#set size of teilstrichbeschriftungen
ax.tick_params(axis="both", labelsize=14)

# %%
plt.show()

# %%
input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]

fig, ax = plt.subplots()

ax.plot(input_values, squares, linewidth=3)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
#use styles
input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]

plt.style.use("seaborn-v0_8")
fig, ax = plt.subplots()

ax.plot(input_values, squares, linewidth=3)

# %%
plt.style.use("_mpl-gallery-nogrid")
fig, ax = plt.subplots()

ax.plot(input_values, squares, linewidth=3)

# %%
plt.style.use("petroff10")
fig, ax = plt.subplots()

ax.plot(input_values, squares, linewidth=3)

# %%
plt.style.use("tableau-colorblind10")
fig, ax = plt.subplots()

ax.plot(input_values, squares, linewidth=3)

# %%
plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots()

ax.plot(input_values, squares, linewidth=3)

# %%
#scatter
plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots()

ax.scatter(2, 4)

plt.show()

# %%
plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots()

ax.scatter(2, 4, s=200)

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

#set size of teilstrichbeschriftungen
ax.tick_params(labelsize=14)

# %%
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots()

ax.scatter(x_values, y_values, s=100)

# %%
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=10)

ax.axis([0, 1100, 0, 1100000])

plt.show()

# %%
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=10)

ax.axis([0, 1100, 0, 1_100_000])
ax.ticklabel_format(style="plain")

plt.show()

# %%
#einige Farben festlegen
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

fig, ax = plt.subplots()
ax.scatter(x_values, y_values, color="red", s=10)

ax.axis([0, 1100, 0, 1_100_000])
ax.ticklabel_format(style="plain")

plt.show()

# %%
#einige Farben festlegen
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

fig, ax = plt.subplots()
ax.scatter(x_values, y_values, color=(0, .8, 0), s=10)

ax.axis([0, 1100, 0, 1_100_000])
ax.ticklabel_format(style="plain")

plt.show()

# %%
#colourmap
#einige Farben festlegen
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots()

ax.scatter(x_values, y_values, color="blue", s=10)

ax.axis([0, 1100, 0, 1_100_000])
ax.ticklabel_format(style="plain")

plt.show()

# %%
#diagrams save automatically
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots()

ax.scatter(x_values, y_values, color="blue", s=10)

ax.axis([0, 1100, 0, 1_100_000])
ax.ticklabel_format(style="plain")


plt.savefig("squares_plot.png", bbox_inches="tight") #instead of plt.show()

# %%
#Kubikzahlen
#einige Farben festlegen
x_values = range(1, 6)
y_values = [x**3 for x in x_values]

plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots()

ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Reds, s=100)

ax.axis([0, 5, 0, 125])
ax.ticklabel_format(style="plain")

plt.show()

# %%
#Kubikzahlen
#einige Farben festlegen
x_values = range(1, 5001)
y_values = [x**3 for x in x_values]

plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots()

ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Reds, s=10)

ax.axis([0, 5000, 0, 125000000000])
ax.ticklabel_format(style="plain")

plt.show()

# %%
#zufallbewegung
import matplotlib.pyplot as plt
from random import choice

class RandomWalk:
    """A class to generate random walks."""

    def __init__(self, num_points=5000):
        """Initialize attributes of a walk."""
        self.num_points = num_points

        #Alle Bewegungen neginnen nei (0, 0)
        self.x_values = [0]
        self.y_values = [0]

    def fill_walk(self):
        """Calculate all points in the walk"""

        #Führt Schritte aus, bis der Pfad die angegebene Läange erreicht hat.
        while len(self.x_values) < self.num_points:

            #Wählt die Richtung und die Weglänge in dieser Richtung aus.
            x_direction = choice([1, -1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_direction * x_distance

            y_direction = choice([1, -1])
            y_distance = choice([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance

            #Lehnt Bewegung ab, die nicht vom Fleck führen
            if x_step == 0 and y_step == 0:
                continue
            #Berechnet den nächsten x- und y-Wert.
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step

            self.x_values.append(x)
            self.y_values.append(y)

# %%
#Ertstellen einen Zufallspfad
rw = RandomWalk()
rw.fill_walk()

#Gibt die Punkte in einem Diagram aus.
plt.style.use("classic")

fig, ax = plt.subplots()

ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect("equal")

plt.show()

# %%
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk()
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")

    fig, ax = plt.subplots()

    ax.scatter(rw.x_values, rw.y_values, s=15)
    ax.set_aspect("equal")

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
import matplotlib.pyplot as plt
from Random_walk import RandomWalk

#Ertstellen einen Zufallspfad
rw = RandomWalk()
rw.fill_walk()

#Gibt die Punkte in einem Diagram aus.
plt.style.use("classic")

fig, ax = plt.subplots()

ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect("equal")

plt.show()

# %%
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk()
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")

    fig, ax = plt.subplots()

    ax.scatter(rw.x_values, rw.y_values, s=15)
    ax.set_aspect("equal")

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk()
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")

    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)

    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Reds, edgecolors="none", s=15)
    ax.set_aspect("equal")

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
#start und endpunkten zu zeigen
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk()
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")

    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)

    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Reds, edgecolors="none", s=15)
    ax.set_aspect("equal")

    #Hebt den ersten und den letzten Punkt hervor.
    ax.scatter(0, 0, c="green", edgecolors="none", s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c="red", edgecolors="none", s=100)

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
#die achsen entfernen
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk()
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")

    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)

    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Reds, edgecolors="none", s=15)
    ax.set_aspect("equal")

    #Hebt den ersten und den letzten Punkt hervor.
    ax.scatter(0, 0, c="green", edgecolors="none", s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c="red", edgecolors="none", s=100)

    #Entfernt die Achsen
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
#datenpunkte hinzufügen
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk(50_000)
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")

    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)

    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Reds, edgecolors="none", s=1)
    ax.set_aspect("equal")

    #Hebt den ersten und den letzten Punkt hervor.
    ax.scatter(0, 0, c="green", edgecolors="none", s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c="red", edgecolors="none", s=100)

    #Entfernt die Achsen
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
#die Größe anpassen
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk(50_000)
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")

    fig, ax = plt.subplots(figsize=(15, 9))
    point_numbers = range(rw.num_points)

    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Reds, edgecolors="none", s=1)
    ax.set_aspect("equal")

    #Hebt den ersten und den letzten Punkt hervor.
    ax.scatter(0, 0, c="green", edgecolors="none", s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c="red", edgecolors="none", s=100)

    #Entfernt die Achsen
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk(50_000)
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")

    fig, ax = plt.subplots(figsize=(10, 6), dpi=128)
    point_numbers = range(rw.num_points)

    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Reds, edgecolors="none", s=1)
    ax.set_aspect("equal")

    #Hebt den ersten und den letzten Punkt hervor.
    ax.scatter(0, 0, c="green", edgecolors="none", s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c="red", edgecolors="none", s=100)

    #Entfernt die Achsen
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk(50_000)
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")
    plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.tab20c.colors)

    fig, ax = plt.subplots(figsize=(15, 9))
    point_numbers = range(rw.num_points)

    ax.plot(rw.x_values, rw.y_values, linewidth=1, color="orange", zorder=1)

    #Hebt den ersten und den letzten Punkt hervor.
    ax.scatter(0, 0, c="green", edgecolors="none", s=100, zorder=2)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c="red", edgecolors="none", s=100, zorder=3)

    #Entfernt die Achsen
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk(50_000)
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")
    plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.tab20c.colors)

    fig, ax = plt.subplots(figsize=(15, 9))
    point_numbers = range(rw.num_points)

    for i in range(len(rw.x_values)-1):
        ax.plot(rw.x_values[i:i+2], rw.y_values[i:i+2], linewidth=1, color=plt.cm.viridis(i/len(rw.x_values)), zorder=1)

    #Hebt den ersten und den letzten Punkt hervor.
    ax.scatter(0, 0, c="green", edgecolors="none", s=100, zorder=2)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c="red", edgecolors="none", s=100, zorder=3)

    #Entfernt die Achsen
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break

# %%
#Würfeln mit Ploty
from die import Die

#Erstellt einen W6
die = Die()

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste.
results = []
for roll_num in range(100):
    result = die.roll()
    results.append(result)

print(results)
# Out:
# [1, 5, 3, 2, 1, 5, 6, 4, 3, 5, 1, 2, 1, 1, 1, 1, 6, 2, 6, 5, 6, 4, 5, 2, 3, 1, 4, 2, 3, 4, 2, 4, 3, 6, 3, 5, 1, 1, 6, 4, 1, 3, 6, 3, 4, 4, 6, 4, 3, 3, 2, 1, 2, 5, 3, 4, 1, 2, 6, 4, 3, 5, 2, 5, 3, 3, 6, 5, 1, 1, 5, 5, 1, 2, 6, 6, 3, 4, 6, 6, 3, 2, 4, 2, 5, 1, 3, 5, 3, 3, 4, 6, 1, 2, 1, 2, 3, 3, 1, 2]

# %%
#Würfeln mit Ploty
from die import Die

#Erstellt einen W6
die = Die()

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste.
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)

#Analysiert die Ergebnisse.
frequencies = []
poss_results = range(1, die.num_sides + 1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

print(frequencies)
# Out:
# [152, 164, 170, 196, 141, 177]

# %%
#Eine Histogramm erstellen
import plotly.express as px 
#Würfeln mit Ploty
from die import Die

#Erstellt einen W6
die = Die()

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste.
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)

#Analysiert die Ergebnisse.
frequencies = []
poss_results = range(1, die.num_sides + 1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

#Stellt die Ergebnis graphisch dar.
fig = px.bar(x=poss_results, y=frequencies)
fig.show()

# %%
#Eine Histogramm erstellen
import plotly.express as px 
import plotly.io as pio


#Würfeln mit Ploty
from die import Die

#to open the diagram in browser
#Credits: Dr. Pardeep and Dr. Vikas.
pio.renderers.default = "browser"


#Erstellt einen W6
die = Die()

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste.
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)

#Analysiert die Ergebnisse.
frequencies = []
poss_results = range(1, die.num_sides + 1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

#Stellt die Ergebnis graphisch dar.
fig = px.bar(x=poss_results, y=frequencies)
fig.show()

# %%
fig = px.scatter(x=poss_results, y=frequencies, size_max=115)
fig.show()

# %%
fig = px.line(x=poss_results, y=frequencies)
fig.show()

# %%
#Eine Histogramm erstellen
import plotly.express as px 
import plotly.io as pio


#Würfeln mit Ploty
from die import Die

#to open the diagram in browser
#Credits: Dr. Pardeep and Dr. Vikas.
pio.renderers.default = "browser"


#Erstellt einen W6
die = Die()

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste.
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)

#Analysiert die Ergebnisse.
frequencies = []
poss_results = range(1, die.num_sides + 1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

#Stellt die Ergebnis graphisch dar.
title = "Results of Rolling One D6 1.000 Times"
labels = {"x": "Result", "y": "Frequency of Result"}
fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
fig.show()

# %%
#Ergebnisse bei Zwei Würfeln
#Eine Histogramm erstellen
import plotly.express as px 
import plotly.io as pio

#Würfeln mit Ploty
from die import Die

#to open the diagram in browser
#Credits: Dr. Pardeep and Dr. Vikas.
pio.renderers.default = "browser"

#Erstellt zwei W6-Würfel
die_1 = Die()
die_2 = Die()

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste
results = []
for roll_num in range(1000):
    result = die_1.roll() + die_2.roll()
    results.append(result)

#Analysiert die Ergebnisse.
frequencies = []
max_result = die_1.num_sides + die_2.num_sides
poss_results = range(2, max_result + 1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

#Stellt die Ergebnis graphisch dar.
title = "Results of Rolling Two D6 1.000 Times"
labels = {"x": "Result", "y": "Frequency of Result"}
fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
fig.show()

# %%
#Ergebnisse bei Zwei Würfeln mit Unterschriften unter alln Balken
#Eine Histogramm erstellen
import plotly.express as px 
import plotly.io as pio

#Würfeln mit Ploty
from die import Die

#to open the diagram in browser
#Credits: Dr. Pardeep and Dr. Vikas.
pio.renderers.default = "browser"

#Erstellt zwei W6-Würfel
die_1 = Die()
die_2 = Die()

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste
results = []
for roll_num in range(1000):
    result = die_1.roll() + die_2.roll()
    results.append(result)

#Analysiert die Ergebnisse.
frequencies = []
max_result = die_1.num_sides + die_2.num_sides
poss_results = range(2, max_result + 1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

#Stellt die Ergebnis graphisch dar.
title = "Results of Rolling Two D6 1.000 Times"
labels = {"x": "Result", "y": "Frequency of Result"}
fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
#Further customize chart.
fig.update_layout(xaxis_dtick=1)

fig.show()

# %%
#Würfel unterschiedlicher Flächenzahl
#Ergebnisse bei Zwei Würfeln mit Unterschriften unter alln Balken
#Eine Histogramm erstellen
import plotly.express as px 
import plotly.io as pio

#Würfeln mit Ploty
from die import Die

#to open the diagram in browser
#Credits: Dr. Pardeep and Dr. Vikas.
pio.renderers.default = "browser"

#Erstellt zwei W6-Würfel
die_1 = Die()
die_2 = Die(10)

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste
results = []
for roll_num in range(50_000):
    result = die_1.roll() + die_2.roll()
    results.append(result)

#Analysiert die Ergebnisse.
frequencies = []
max_result = die_1.num_sides + die_2.num_sides
poss_results = range(2, max_result + 1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

#Stellt die Ergebnis graphisch dar.
title = "Results of Rolling One D6 and One D10 50.000 Times"
labels = {"x": "Result", "y": "Frequency of Result"}
fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
#Further customize chart.
fig.update_layout(xaxis_dtick=1)

fig.show()

# %%
#Diagramme speichern
#Würfel unterschiedlicher Flächenzahl
#Ergebnisse bei Zwei Würfeln mit Unterschriften unter alln Balken
#Eine Histogramm erstellen
import plotly.express as px 
import plotly.io as pio

#Würfeln mit Ploty
from die import Die

#to open the diagram in browser
#Credits: Dr. Pardeep and Dr. Vikas.
pio.renderers.default = "browser"

#Erstellt zwei W6-Würfel
die_1 = Die()
die_2 = Die(10)

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste
results = []
for roll_num in range(50_000):
    result = die_1.roll() + die_2.roll()
    results.append(result)

#Analysiert die Ergebnisse.
frequencies = []
max_result = die_1.num_sides + die_2.num_sides
poss_results = range(2, max_result + 1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

#Stellt die Ergebnis graphisch dar.
title = "Results of Rolling One D6 and One D10 50.000 Times"
labels = {"x": "Result", "y": "Frequency of Result"}
fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
#Further customize chart.
fig.update_layout(xaxis_dtick=1)

fig.write_html("dice_visual_d6d10.html")

# %%
# 15-7 Dre Würfel werfen
#Würfel unterschiedlicher Flächenzahl
#Ergebnisse bei Zwei Würfeln mit Unterschriften unter alln Balken
#Eine Histogramm erstellen
import plotly.express as px 
import plotly.io as pio

#Würfeln mit Ploty
from die import Die

#to open the diagram in browser
#Credits: Dr. Pardeep and Dr. Vikas.
pio.renderers.default = "browser"

#Erstellt zwei W6-Würfel
die_1 = Die()
die_2 = Die()
die_3 = Die()

max_result = die_1.num_sides + die_2.num_sides + die_3.num_sides
poss_results = range(3, max_result + 1)
frequencies = [0 for i in range(len(poss_results))]

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste
for roll_num in range(50_000):
    result = die_1.roll() + die_2.roll() + die_3.roll()
    frequencies[result - 3] += 1

#Analysiert die Ergebnisse.

#Stellt die Ergebnis graphisch dar.
title = "Results of Rolling One D6 and One D10 50.000 Times"
labels = {"x": "Result", "y": "Frequency of Result"}
fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
#Further customize chart.
fig.update_layout(xaxis_dtick=1)

fig.show()

# %%
#15-6
#Würfel unterschiedlicher Flächenzahl
#Ergebnisse bei Zwei Würfeln mit Unterschriften unter alln Balken
#Eine Histogramm erstellen
import plotly.express as px 
import plotly.io as pio

#Würfeln mit Ploty
from die import Die

#to open the diagram in browser
#Credits: Dr. Pardeep and Dr. Vikas.
pio.renderers.default = "browser"

#Erstellt zwei W6-Würfel
die_1 = Die(8)
die_2 = Die(8)

max_result = die_1.num_sides + die_2.num_sides
poss_results = range(2, max_result + 1)
frequencies = [0 for i in range(len(poss_results))]

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste
for roll_num in range(500_000):
    result = die_1.roll() + die_2.roll()
    frequencies[result - 2] += 1

#Analysiert die Ergebnisse.

#Stellt die Ergebnis graphisch dar.
title = "Results of Rolling One D6 and One D10 50.000 Times"
labels = {"x": "Result", "y": "Frequency of Result"}
fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
#Further customize chart.
fig.update_layout(xaxis_dtick=1)

fig.show()

# %%
#make Würfelvorgang mit Matplotlib
import matplotlib.pyplot as plt
import numpy as np

from die import Die


#Erstellt zwei W6-Würfel
die_1 = Die(8)
die_2 = Die(8)

max_result = die_1.num_sides + die_2.num_sides
poss_results = range(2, max_result + 1)
frequencies = [0 for i in range(len(poss_results))]

#Würfelt mehrere Male und speichert die Ergebnisse in einer Liste
for roll_num in range(5_000):
    result = die_1.roll() + die_2.roll()
    frequencies[result - 2] += 1

width = 0.8 # width of the bars
fig, ax = plt.subplots(figsize=(15, 9))
plt.bar(poss_results, frequencies, width=width, bottom=None, align='center', data=None)



for i in poss_results:
    plt.text(i,frequencies[i - 2] // 2,frequencies[i - 2], ha = 'center')


#set labels to all bars
x = np.arange(2, max_result + 1)  # the label locations
ax.set_xticks(x) # set the position of the x ticks
ax.set_xticklabels(poss_results)
plt.show()
# Out:
# range(2, 17)

# %%
#Erstellt neue Pfade, solange das Program aktiv ist.
while True:
    ##Ertstellen einen Zufallspfad
    rw = RandomWalk(50_000)
    rw.fill_walk()

    #Gibt die Punkte in einem Diagram aus.
    plt.style.use("classic")
    plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.tab20c.colors)

    fig, ax = plt.subplots(figsize=(15, 9))
    point_numbers = range(rw.num_points)

    for i in range(len(rw.x_values)-1):
        ax.plot(rw.x_values[i:i+2], rw.y_values[i:i+2], linewidth=1, color=plt.cm.viridis(i/len(rw.x_values)), zorder=1)

    #Hebt den ersten und den letzten Punkt hervor.
    ax.scatter(0, 0, c="green", edgecolors="none", s=100, zorder=2)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c="red", edgecolors="none", s=100, zorder=3)

    #Entfernt die Achsen
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    plt.show()
    keep_runnung = input("Make another walk? (y, n): ")
    if keep_runnung == "n":
        break
